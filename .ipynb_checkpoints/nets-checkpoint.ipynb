# %% [markdown]
# # Getting Started with Neural Networks (Using Keras)
#
#
# We focus on feedforward nets, and we use the MNIST data set as an example.

# %% [markdown]
# ### Step 1: data visualization and preprocessing

# %%
# install tensorflow...because it doesn't come with anaconda
import numpy as np
from tensorflow import keras

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
print('training data set size for inputs: ', x_train.shape)
print('training data set size for outputs: ', y_train.shape)
print('test data set size for inputs: ', x_test.shape)
print('test data set size for outputs: ', y_test.shape)
# Out:
# training data set size for inputs:  (60000, 28, 28)
# training data set size for outputs:  (60000,)

# %%
# plot some of the input images
import matplotlib.pyplot as plt
# %matplotlib inline

num_row = 2
num_col = 5
fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
for i in range(num_row*num_col):
    ax = axes[i//num_col, i%num_col]
    ax.imshow(x_train[i,:,:], cmap='gray')
    ax.set_title('Label: {}'.format(y_train[i]))
plt.tight_layout()
plt.show()

# %%
# print first image before
#print(x_train[0,:,:])

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# convert class vectors to binary class matrices
# need to do this with cross entropy loss func
num_classes=10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Model 1: 0 Hidden Layers

# %%
# softmax regression
reg_model = keras.Sequential(
    [
        keras.Input(shape=(28,28,1)),
        keras.layers.Flatten(),
        keras.layers.Dense(num_classes, activation="softmax"),
    ]
)
reg_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# estimate parameters
batch_size = 10
epochs = 20
reg_model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])
results = reg_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/20
# 6000/6000 [==============================] - 4s 593us/step - loss: 0.7807 - accuracy: 0.8069
# Epoch 2/20
# 6000/6000 [==============================] - 4s 587us/step - loss: 0.3648 - accuracy: 0.9004
# Epoch 3/20
# 6000/6000 [==============================] - 3s 583us/step - loss: 0.3327 - accuracy: 0.9073
# Epoch 4/20
# 6000/6000 [==============================] - 3s 572us/step - loss: 0.3195 - accuracy: 0.9092
# Epoch 5/20
# 6000/6000 [==============================] - 4s 591us/step - loss: 0.3103 - accuracy: 0.9130
# Epoch 6/20
# 6000/6000 [==============================] - 3s 576us/step - loss: 0.2962 - accuracy: 0.9173
# Epoch 7/20
# 6000/6000 [==============================] - 3s 580us/step - loss: 0.3029 - accuracy: 0.9142
# Epoch 8/20
# 6000/6000 [==============================] - 3s 581us/step - loss: 0.2880 - accuracy: 0.9193
# Epoch 9/20
# 6000/6000 [==============================] - 4s 589us/step - loss: 0.2899 - accuracy: 0.9198
# Epoch 10/20
# 6000/6000 [==============================] - 3s 581us/step - loss: 0.2828 - accuracy: 0.9209
# Epoch 11/20
# 6000/6000 [==============================] - 4s 598us/step - loss: 0.2812 - accuracy: 0.9220
# Epoch 12/20
# 6000/6000 [==============================] - 3s 578us/step - loss: 0.2773 - accuracy: 0.9225
# Epoch 13/20
# 6000/6000 [==============================] - 3s 580us/step - loss: 0.2770 - accuracy: 0.9226
# Epoch 14/20
# 6000/6000 [==============================] - 4s 589us/step - loss: 0.2757 - accuracy: 0.9236
# Epoch 15/20
# 6000/6000 [==============================] - 4s 587us/step - loss: 0.2771 - accuracy: 0.9231
# Epoch 16/20
# 6000/6000 [==============================] - 3s 580us/step - loss: 0.2718 - accuracy: 0.9236
# Epoch 17/20
# 6000/6000 [==============================] - 3s 576us/step - loss: 0.2762 - accuracy: 0.9236
# Epoch 18/20
# 6000/6000 [==============================] - 3s 582us/step - loss: 0.2695 - accuracy: 0.9243
# Epoch 19/20
# 6000/6000 [==============================] - 3s 583us/step - loss: 0.2712 - accuracy: 0.9252
# Epoch 20/20
# 6000/6000 [==============================] - 4s 592us/step - loss: 0.2663 - accuracy: 0.9247

# %%
# plot loss improvement
plt.plot(results.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# evaluate out of sample accuracy
score = reg_model.evaluate(x_test, y_test)
#print("Test loss:", score[0])

print("Test accuracy:", np.round(score[1]*100, 2), "%")
# Out:
# 313/313 [==============================] - 0s 581us/step - loss: 0.2707 - accuracy: 0.9230
# Test accuracy: 92.3 %

# %%
# visualize weights
print("the W weight matrix has shape ", reg_model.weights[0].shape)
num_row = 2
num_col = 5
fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
W = reg_model.weights[0]
for which_label in range(num_row*num_col):
    ax = axes[which_label//num_col, which_label%num_col]
    column_of_W = np.array(W[:,which_label]).reshape((28,28))
    ax.imshow(column_of_W, cmap='gray')
    ax.set_title('Label: {}'.format(which_label))
# Out:
# the W weight matrix has shape  (784, 10)

# %% [markdown]
# # Model 2: Adding 1 Hidden Layer

# %%
# one hidden layer 
one_hidden_model = keras.Sequential(
    [
        keras.Input(shape=(28,28,1)),
        keras.layers.Flatten(),
        keras.layers.Dense(64, activation="relu"),   # <------- new!
        keras.layers.Dense(num_classes, activation="softmax"),
    ]
)
one_hidden_model.summary()
batch_size = 10
epochs = 20
one_hidden_model.compile(loss="categorical_crossentropy", 
                         optimizer="SGD", metrics=["accuracy"])
results = one_hidden_model.fit(x_train, 
                               y_train, 
                               batch_size=batch_size, 
                               epochs=epochs)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 6000/6000 [==============================] - 4s 694us/step - loss: 0.7072 - accuracy: 0.8099
# Epoch 2/20
# 6000/6000 [==============================] - 4s 664us/step - loss: 0.2576 - accuracy: 0.9270
# Epoch 3/20
# 6000/6000 [==============================] - 4s 697us/step - loss: 0.2070 - accuracy: 0.9415
# Epoch 4/20
# 6000/6000 [==============================] - 4s 693us/step - loss: 0.1700 - accuracy: 0.9511
# Epoch 5/20
# 6000/6000 [==============================] - 4s 686us/step - loss: 0.1451 - accuracy: 0.9588
# Epoch 6/20
# 6000/6000 [==============================] - 4s 670us/step - loss: 0.1307 - accuracy: 0.9640
# Epoch 7/20
# 6000/6000 [==============================] - 4s 641us/step - loss: 0.1182 - accuracy: 0.9664
# Epoch 8/20
# 6000/6000 [==============================] - 4s 675us/step - loss: 0.1034 - accuracy: 0.9710
# Epoch 9/20
# 6000/6000 [==============================] - 4s 668us/step - loss: 0.0988 - accuracy: 0.9716
# Epoch 10/20
# 6000/6000 [==============================] - 4s 652us/step - loss: 0.0868 - accuracy: 0.9749
# Epoch 11/20
# 6000/6000 [==============================] - 4s 656us/step - loss: 0.0832 - accuracy: 0.9768
# Epoch 12/20
# 6000/6000 [==============================] - 4s 655us/step - loss: 0.0776 - accuracy: 0.9782
# Epoch 13/20
# 6000/6000 [==============================] - 4s 679us/step - loss: 0.0735 - accuracy: 0.9797
# Epoch 14/20
# 6000/6000 [==============================] - 4s 672us/step - loss: 0.0682 - accuracy: 0.9807
# Epoch 15/20
# 6000/6000 [==============================] - 4s 670us/step - loss: 0.0643 - accuracy: 0.9821
# Epoch 16/20
# 6000/6000 [==============================] - 4s 696us/step - loss: 0.0615 - accuracy: 0.9829
# Epoch 17/20
# 6000/6000 [==============================] - 4s 682us/step - loss: 0.0561 - accuracy: 0.9842
# Epoch 18/20
# 6000/6000 [==============================] - 4s 676us/step - loss: 0.0537 - accuracy: 0.9860
# Epoch 19/20
# 6000/6000 [==============================] - 4s 671us/step - loss: 0.0521 - accuracy: 0.9858
# Epoch 20/20
# 6000/6000 [==============================] - 4s 674us/step - loss: 0.0500 - accuracy: 0.9866

# %%
# plot loss improvement
plt.plot(results.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

# %%
# evaluate out of sample accuracy
one_h_score = one_hidden_model.evaluate(x_test, y_test)
print("Test accuracy:", 100*one_h_score[1])
# Out:
# 313/313 [==============================] - 0s 567us/step - loss: 0.0826 - accuracy: 0.9752
# Test accuracy: 97.51999974250793

# %%
# visualize weights of the hidden layer
# this is pre-nonlinearity
num_row = 8
num_col = 8
fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
hiddenW = one_hidden_model.weights[0]
for which_label in range(num_row*num_col):
    ax = axes[which_label//num_col, which_label%num_col]
    column_of_W = np.array(hiddenW[:,which_label]).reshape((28,28))
    ax.imshow(column_of_W, cmap='gray')
    #ax.set_title('Label: {}'.format(which_label))

# %%
# visualize which hidden layer units light up on different inputs
def vis_inputs_and_features(input_num):

    # set everything up
    fig, axes = plt.subplots(3, 1, figsize=(1.5,6))
    vis_mod = keras.models.Model(
        inputs=one_hidden_model.input, 
        outputs=[layer.output for layer in one_hidden_model.layers])
    vis_outs = vis_mod.predict(x_test)
    
    # plot input
    ax = axes[0]
    out1 = vis_outs[0][input_num]
    ax.imshow(out1.reshape((28,28)), cmap='gray')
    ax.set_title('raw input')

    # plot hidden relu layer
    ax = axes[1]
    out2 = vis_outs[1][input_num]
    ax.imshow(out2.reshape((8,8)), cmap='gray')
    ax.set_title('hidden layer (post nonlinearity)')

    # plot softmax output
    ax = axes[2]
    out3 = vis_outs[2][input_num]
    ax.imshow(np.expand_dims(out3, 0), cmap='gray')
    ax.set_title('softmax output prob.s')

# %%
vis_inputs_and_features(1)

# %% [markdown]
# # Model 3: a Convolutional Neural Network

# %%
# two hidden layers. first one is a cnn filter
img_shape = (28,28,1)
cnn_model = keras.Sequential([
        keras.Input(shape=img_shape),
        keras.layers.Conv2D(32, kernel_size=(3, 3), input_shape = img_shape, activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dense(64, activation="relu"),   
        keras.layers.Dense(num_classes, activation="softmax"),
    ])
cnn_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                346176
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                650
# =================================================================
# Total params: 347,146
# Trainable params: 347,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit CNN (takes much longer)
batch_size = 10
epochs = 20
cnn_model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])
results = cnn_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.5212 - accuracy: 0.8507
# Epoch 2/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.1571 - accuracy: 0.9532
# Epoch 3/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.1136 - accuracy: 0.9661
# Epoch 4/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0860 - accuracy: 0.9733
# Epoch 5/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0686 - accuracy: 0.9789
# Epoch 6/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0548 - accuracy: 0.9833
# Epoch 7/20
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.0493 - accuracy: 0.9845
# Epoch 8/20
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.0398 - accuracy: 0.9881
# Epoch 9/20
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.0366 - accuracy: 0.9887
# Epoch 10/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0285 - accuracy: 0.9916
# Epoch 11/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0255 - accuracy: 0.9924
# Epoch 12/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0225 - accuracy: 0.9935
# Epoch 13/20
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.0203 - accuracy: 0.9941
# Epoch 14/20
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.0167 - accuracy: 0.9954
# Epoch 15/20
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.0150 - accuracy: 0.9959
# Epoch 16/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0143 - accuracy: 0.9965
# Epoch 17/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0115 - accuracy: 0.9974
# Epoch 18/20
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.0096 - accuracy: 0.9975
# Epoch 19/20
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.0093 - accuracy: 0.9978
# Epoch 20/20
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.0074 - accuracy: 0.9986

# %%
# plot loss improvement
plt.plot(results.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# evaluate out of sample accuracy
cnn_score = cnn_model.evaluate(x_test, y_test)
print("Test accuracy:", 100*cnn_score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0516 - accuracy: 0.9851
# Test accuracy: 98.50999712944031

# %%
# visualize weights of the cnn hidden layer
# this is pre-nonlinearity
num_row = 4
num_col = 8
fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
hiddenW = cnn_model.weights[0]
for which_label in range(num_row*num_col):
    ax = axes[which_label//num_col, which_label%num_col]
    this_kernel = np.array(hiddenW[:,:,0,which_label])
    ax.imshow(this_kernel, cmap='gray')
    #ax.set_title('Label: {}'.format(which_label))

# %%
# visualize a single kernel (32 available) applied to input image
# this is pre-nonlinearity again
def vis_convolution(which_input):
    """visualize an input and the outputs from all your kernels"""
    input_img = x_test[which_input,:,:,0]
    
    # set up plotting stuff
    output_images = []
    for which_kernel in range(32):
        my_kernel = cnn_model.weights[0][:,:,0,which_kernel]
        output_img = np.empty((26,26))
        for row in range(26):
            for col in range(26):
                output_img[row,col] = np.sum(input_img[row:row+3,col:col+3] * my_kernel)
                
        output_images.append(output_img)

    # plot input next to all outputs
    num_row = 5
    num_col = 7
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*6,2*6))
    for j in range(1,33):
        i = j-1
        ax = axes[i//num_col, i%num_col]
        ax.imshow(output_images[i], cmap='gray')
    
    axes[4,4].imshow(input_img, cmap='gray')
    axes[4,4].set_title('input')

# %%
vis_convolution(0)

# %%
# visualize a single kernel (32 available) applied to input image
# this is pre-nonlinearity again
def vis_max_pool(which_input):
    """visualize an input and the outputs from all your kernels"""
    input_img = x_test[which_input,:,:,0]

    # get max pool layer outputs
    tmp_mp_vis_mod = keras.Model(inputs=cnn_model.input, outputs=cnn_model.get_layer(index=1).output)
    mp_out = tmp_mp_vis_mod.predict(x_test)
    #mp_out[which_input,:,:,which_kernel]

    # plot input next to all outputs
    num_row = 5
    num_col = 7
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*6,2*6))
    for which_kernel in range(32):
        ax = axes[which_kernel//num_col, which_kernel%num_col]
        ax.imshow(mp_out[which_input,:,:,which_kernel], cmap='gray')
    
    axes[4,4].imshow(input_img, cmap='gray')
    axes[4,4].set_title('input')
    
vis_max_pool(0)

# %% [markdown]
# ### sources
#
# https://github.com/keras-team/keras-io/blob/master/examples/vision/mnist_convnet.py
#
# https://www.deeplearningbook.org
#
# http://alexlenail.me/NN-SVG/LeNet.html
#
# https://keras.io/examples/vision/visualizing_what_convnets_learn/
